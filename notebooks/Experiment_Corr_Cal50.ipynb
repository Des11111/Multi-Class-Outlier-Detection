# %% [markdown]
# # Correlation of MAMCOD p-values
#
# This is to figure out whether MAMCOD p-values are Positively Correlated

# %% [markdown]
# ### Setup

# %%
# This helps when you're loading functions defined in an external script (if the script is updated while the notebook is running)
# %load_ext autoreload 
# %autoreload 2

import numpy as np
from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from sklearn.decomposition import PCA
from math import sqrt
from sklearn.preprocessing import StandardScaler

import sys
sys.path.append("..")

from mypackage.data_models import generate_data_uniform_plus_normal
from mypackage.MAMCOD_procedure import compute_standard_conformal_scores, compute_MAMCOD_conformal_pv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Parameters

# %%
np.random.seed(100)
# Generate data
K = 2
dim = 50
means = [1, -1]
radius= 10
a_signal= 8
 
num_iterations= 100 #total times of repeating
num_repeats = 100

# Training data
n_in_train = [1000,1000]

# Calibration data
n_in_cal = [50,50]

# Test data
n_in_test = [2,2]
n_out_test = 0
n_test = np.sum(n_in_test) + n_out_test

# %%
# Define machine learning models
from sklearn.svm import SVC, OneClassSVM
from sklearn.ensemble import RandomForestClassifier

binary_classifier = SVC(C=1, probability=True)
oneclass_classifier = OneClassSVM(gamma='auto')
classifier_callable = lambda: OneClassSVM(gamma='auto')

# %% [markdown]
# ## Compute Correlation

# %%
# To store correlations for each pair of test data across iterations
all_correlations = []

# Perform num_iterations
for _ in range(num_iterations):
    # Initialize matrix to store p-values for each repetition
    MAMCOD_pv_matrix = np.zeros((num_repeats, n_test))
    
    # Data Generation
    X_train, Y_train = generate_data_uniform_plus_normal(K, n_in_train, 0, dim, means, radius, a_signal)

    # Repeat the procedure and combine results into a matrix
    for i in range(num_repeats):
        # Data Generation
        X_cal, Y_cal = generate_data_uniform_plus_normal(K, n_in_cal, 0, dim, means, radius, a_signal)
        X_test, Y_test = generate_data_uniform_plus_normal(K, n_in_test, n_out_test, dim, means, radius, a_signal)

        # Compute the conformity scores
        scores_cal, scores_test = compute_standard_conformal_scores(X_train, Y_train, X_cal, Y_cal, X_test, classifier_callable) #scores_test is a m*K matrix

        # Compute MAMCOD pv
        MAMCOD_pv_matrix[i, :] = compute_MAMCOD_conformal_pv(K, n_in_cal, scores_cal, scores_test)
        print(f'Repeating times: {i}, Iteration times: {_}')
        print(MAMCOD_pv_matrix[i, :])
        
    # Compute the covariance matrix
    cov_matrix = np.corrcoef(MAMCOD_pv_matrix.T)

    # Collect correlations for each pair of test data points
    all_correlations.append(cov_matrix[np.triu_indices_from(cov_matrix, k=1)])

# Combine all correlations into a single array for boxplot
all_correlations = np.array(all_correlations).T
# Out:
# Repeating times: 0, Iteration times: 0
# [0.56862745 0.82352941 0.56862745 0.96078431]
# Repeating times: 1, Iteration times: 0
# [0.58823529 0.96078431 0.80392157 0.58823529]
# Repeating times: 2, Iteration times: 0
# [0.84313725 0.64705882 0.74509804 0.64705882]
# Repeating times: 3, Iteration times: 0
# [0.50980392 0.96078431 1.         0.50980392]
# Repeating times: 4, Iteration times: 0
# [0.7254902  0.50980392 0.50980392 0.84313725]
# Repeating times: 5, Iteration times: 0
# [0.54901961 0.90196078 0.54901961 0.54901961]
# Repeating times: 6, Iteration times: 0
# [0.94117647 0.88235294 0.98039216 0.56862745]
# Repeating times: 7, Iteration times: 0
# [0.64705882 0.98039216 0.70588235 0.96078431]
# Repeating times: 8, Iteration times: 0
# [0.60784314 0.66666667 0.7254902  0.60784314]
# Repeating times: 9, Iteration times: 0
# [0.94117647 0.7254902  0.7254902  0.56862745]
# Repeating times: 10, Iteration times: 0
# [0.80392157 0.49019608 0.49019608 0.7254902 ]
# Repeating times: 11, Iteration times: 0
# [0.50980392 0.54901961 0.78431373 0.54901961]
# Repeating times: 12, Iteration times: 0
# [0.50980392 0.84313725 0.50980392 0.50980392]
# Repeating times: 13, Iteration times: 0
# [0.54901961 0.7254902  0.66666667 0.96078431]
# Repeating times: 14, Iteration times: 0
# [0.56862745 0.56862745 0.82352941 0.74509804]
# Repeating times: 15, Iteration times: 0
# [0.56862745 0.56862745 0.56862745 0.56862745]
# Repeating times: 16, Iteration times: 0
# [0.56862745 0.82352941 0.76470588 0.84313725]
# Repeating times: 17, Iteration times: 0
# [0.50980392 0.50980392 0.58823529 0.50980392]
# Repeating times: 18, Iteration times: 0
# [0.7254902  0.80392157 0.90196078 0.52941176]
# Repeating times: 19, Iteration times: 0
# [0.66666667 0.56862745 1.         1.        ]
# Repeating times: 20, Iteration times: 0
# [0.56862745 0.56862745 0.56862745 0.7254902 ]
# Repeating times: 21, Iteration times: 0
# [0.50980392 0.50980392 0.50980392 0.82352941]
# Repeating times: 22, Iteration times: 0
# [0.88235294 0.56862745 0.56862745 0.64705882]
# Repeating times: 23, Iteration times: 0
# [0.50980392 0.74509804 0.58823529 0.50980392]
# Repeating times: 24, Iteration times: 0
# [0.94117647 0.52941176 0.52941176 0.64705882]
# Repeating times: 25, Iteration times: 0
# [0.98039216 0.7254902  0.94117647 0.7254902 ]
# Repeating times: 26, Iteration times: 0
# [0.70588235 0.94117647 0.80392157 1.        ]
# Repeating times: 27, Iteration times: 0
# [0.43137255 0.7254902  0.43137255 0.43137255]
# Repeating times: 28, Iteration times: 0
# [0.98039216 0.50980392 0.50980392 0.96078431]
# Repeating times: 29, Iteration times: 0
# [0.54901961 0.66666667 0.50980392 0.66666667]
# Repeating times: 30, Iteration times: 0
# [0.70588235 0.60784314 0.74509804 0.82352941]
# Repeating times: 31, Iteration times: 0
# [0.8627451  0.47058824 0.94117647 0.70588235]
# Repeating times: 32, Iteration times: 0
# [0.90196078 0.94117647 0.90196078 0.54901961]
# Repeating times: 33, Iteration times: 0
# [0.60784314 0.76470588 0.82352941 0.78431373]
# Repeating times: 34, Iteration times: 0
# [0.60784314 0.60784314 0.7254902  0.7254902 ]
# Repeating times: 35, Iteration times: 0
# [0.60784314 0.60784314 0.60784314 0.80392157]
# Repeating times: 36, Iteration times: 0
# [0.58823529 0.58823529 0.58823529 0.7254902 ]
# Repeating times: 37, Iteration times: 0
# [0.52941176 0.80392157 0.52941176 0.96078431]
# Repeating times: 38, Iteration times: 0
# [0.76470588 0.56862745 1.         0.56862745]
# Repeating times: 39, Iteration times: 0
# [0.78431373 0.64705882 0.64705882 0.74509804]
# Repeating times: 40, Iteration times: 0
# [0.54901961 0.82352941 0.84313725 0.54901961]
# Repeating times: 41, Iteration times: 0
# [0.52941176 0.52941176 1.         0.52941176]
# Repeating times: 42, Iteration times: 0
# [0.54901961 0.49019608 0.68627451 0.90196078]
# Repeating times: 43, Iteration times: 0
# [0.80392157 0.45098039 0.52941176 0.45098039]
# Repeating times: 44, Iteration times: 0
# [0.45098039 0.70588235 0.64705882 0.45098039]
# Repeating times: 45, Iteration times: 0
# [0.58823529 0.74509804 0.58823529 0.58823529]
# Repeating times: 46, Iteration times: 0
# [0.64705882 0.66666667 0.47058824 0.52941176]
# Repeating times: 47, Iteration times: 0
# [0.58823529 0.78431373 0.84313725 0.82352941]
# Repeating times: 48, Iteration times: 0
# [0.66666667 0.52941176 0.60784314 0.52941176]
# Repeating times: 49, Iteration times: 0
# [0.74509804 0.74509804 0.74509804 0.60784314]
# Repeating times: 50, Iteration times: 0
# [0.58823529 0.8627451  0.8627451  0.58823529]
# Repeating times: 51, Iteration times: 0
# [0.80392157 0.98039216 0.60784314 0.60784314]
# Repeating times: 52, Iteration times: 0
# [0.96078431 0.54901961 0.62745098 0.52941176]
# Repeating times: 53, Iteration times: 0
# [0.78431373 0.52941176 0.82352941 0.52941176]
# Repeating times: 54, Iteration times: 0
# [0.50980392 0.60784314 0.88235294 0.50980392]
# Repeating times: 55, Iteration times: 0
# [0.96078431 0.54901961 0.54901961 0.54901961]
# Repeating times: 56, Iteration times: 0
# [0.49019608 0.96078431 0.62745098 0.62745098]
# Repeating times: 57, Iteration times: 0
# [0.58823529 0.58823529 0.70588235 0.58823529]
# Repeating times: 58, Iteration times: 0
# [0.49019608 0.96078431 0.49019608 0.66666667]
# Repeating times: 59, Iteration times: 0
# [0.7254902  0.92156863 0.62745098 0.62745098]
# Repeating times: 60, Iteration times: 0
# [1.         0.64705882 1.         0.7254902 ]
# Repeating times: 61, Iteration times: 0
# [0.64705882 0.52941176 0.94117647 0.52941176]
# Repeating times: 62, Iteration times: 0
# [0.62745098 0.50980392 0.66666667 0.50980392]
# Repeating times: 63, Iteration times: 0
# [0.50980392 0.50980392 0.52941176 0.50980392]
# Repeating times: 64, Iteration times: 0
# [0.66666667 0.52941176 0.78431373 0.70588235]
# Repeating times: 65, Iteration times: 0
# [0.49019608 0.49019608 0.49019608 0.92156863]
# Repeating times: 66, Iteration times: 0
# [0.76470588 1.         0.66666667 0.7254902 ]
# Repeating times: 67, Iteration times: 0
# [0.62745098 0.62745098 0.68627451 0.64705882]
# Repeating times: 68, Iteration times: 0
# [0.50980392 0.88235294 0.50980392 0.50980392]
# Repeating times: 69, Iteration times: 0
# [0.54901961 0.96078431 1.         0.82352941]
# Repeating times: 70, Iteration times: 0
# [0.84313725 0.98039216 1.         0.84313725]
# Repeating times: 71, Iteration times: 0
# [0.60784314 0.92156863 0.60784314 0.60784314]
# Repeating times: 72, Iteration times: 0
# [0.49019608 0.49019608 0.66666667 0.49019608]
# Repeating times: 73, Iteration times: 0
# [0.82352941 0.74509804 0.52941176 0.68627451]
# Repeating times: 74, Iteration times: 0
# [0.64705882 0.70588235 0.52941176 0.52941176]
# Repeating times: 75, Iteration times: 0
# [0.78431373 0.84313725 0.78431373 0.70588235]
# Repeating times: 76, Iteration times: 0
# [0.49019608 0.49019608 0.76470588 0.49019608]
# Repeating times: 77, Iteration times: 0
# [0.60784314 0.94117647 0.96078431 0.94117647]
# Repeating times: 78, Iteration times: 0
# [0.56862745 0.56862745 0.98039216 0.56862745]
# Repeating times: 79, Iteration times: 0
# [0.54901961 1.         0.7254902  0.54901961]
# Repeating times: 80, Iteration times: 0
# [0.70588235 0.74509804 0.52941176 0.68627451]
# Repeating times: 81, Iteration times: 0
# [0.54901961 0.54901961 0.8627451  0.90196078]
# Repeating times: 82, Iteration times: 0
# [0.45098039 0.45098039 0.54901961 0.45098039]
# Repeating times: 83, Iteration times: 0
# [0.74509804 0.82352941 0.56862745 0.56862745]
# Repeating times: 84, Iteration times: 0
# [0.56862745 1.         0.56862745 0.62745098]
# Repeating times: 85, Iteration times: 0
# [1.         0.60784314 0.88235294 0.98039216]
# Repeating times: 86, Iteration times: 0
# [0.80392157 0.56862745 0.88235294 0.56862745]
# Repeating times: 87, Iteration times: 0
# [0.50980392 0.50980392 0.50980392 0.82352941]
# Repeating times: 88, Iteration times: 0
# [0.64705882 0.84313725 0.70588235 0.60784314]
# Repeating times: 89, Iteration times: 0
# [0.92156863 0.82352941 0.50980392 0.68627451]
# Repeating times: 90, Iteration times: 0
# [0.54901961 0.54901961 0.54901961 0.54901961]
# Repeating times: 91, Iteration times: 0
# [0.62745098 0.8627451  0.54901961 0.92156863]
# Repeating times: 92, Iteration times: 0
# [0.78431373 0.52941176 0.94117647 0.7254902 ]
# Repeating times: 93, Iteration times: 0
# [0.60784314 0.94117647 0.78431373 0.84313725]
# Repeating times: 94, Iteration times: 0
# [0.98039216 0.8627451  0.92156863 0.60784314]
# Repeating times: 95, Iteration times: 0
# [0.54901961 0.62745098 0.50980392 0.82352941]
# Repeating times: 96, Iteration times: 0
# [0.58823529 0.58823529 0.80392157 0.7254902 ]
# Repeating times: 97, Iteration times: 0
# [0.58823529 0.60784314 0.82352941 0.70588235]
# Repeating times: 98, Iteration times: 0
# [1.         0.76470588 0.96078431 0.60784314]
# Repeating times: 99, Iteration times: 0
# [0.62745098 0.76470588 0.62745098 0.96078431]
# Repeating times: 0, Iteration times: 1
# [0.52941176 0.80392157 0.52941176 0.92156863]
# Repeating times: 1, Iteration times: 1
# [0.52941176 0.52941176 0.88235294 0.7254902 ]
# Repeating times: 2, Iteration times: 1
# [0.94117647 0.49019608 0.56862745 0.8627451 ]
# Repeating times: 3, Iteration times: 1
# [0.74509804 0.43137255 0.88235294 0.50980392]
# Repeating times: 4, Iteration times: 1
# [0.50980392 0.50980392 0.68627451 0.60784314]
# Repeating times: 5, Iteration times: 1
# [0.76470588 0.80392157 0.58823529 0.80392157]
# Repeating times: 6, Iteration times: 1
# [0.54901961 0.54901961 0.70588235 0.80392157]
# Repeating times: 7, Iteration times: 1
# [0.74509804 0.74509804 0.7254902  0.84313725]
# Repeating times: 8, Iteration times: 1
# [0.98039216 0.8627451  0.49019608 0.49019608]
# Repeating times: 9, Iteration times: 1
# [0.80392157 0.82352941 0.94117647 0.58823529]
# Repeating times: 10, Iteration times: 1
# [0.76470588 0.54901961 0.54901961 0.90196078]
# Repeating times: 11, Iteration times: 1
# [0.54901961 0.54901961 0.66666667 0.54901961]
# Repeating times: 12, Iteration times: 1
# [0.58823529 0.45098039 0.45098039 0.58823529]
# Repeating times: 13, Iteration times: 1
# [0.54901961 0.54901961 0.54901961 0.54901961]
# Repeating times: 14, Iteration times: 1
# [0.92156863 0.92156863 0.58823529 0.98039216]
# Repeating times: 15, Iteration times: 1
# [0.47058824 0.47058824 0.64705882 0.84313725]
# Repeating times: 16, Iteration times: 1
# [0.45098039 0.60784314 0.45098039 0.45098039]
# Repeating times: 17, Iteration times: 1
# [0.64705882 0.64705882 1.         0.92156863]
# Repeating times: 18, Iteration times: 1
# [0.76470588 0.64705882 0.68627451 0.64705882]
# Repeating times: 19, Iteration times: 1
# [0.98039216 0.56862745 0.56862745 0.56862745]
# Repeating times: 20, Iteration times: 1
# [0.54901961 0.54901961 0.54901961 0.66666667]
# Repeating times: 21, Iteration times: 1
# [0.76470588 0.96078431 0.56862745 0.56862745]
# Repeating times: 22, Iteration times: 1
# [0.92156863 0.82352941 0.76470588 0.52941176]
# Repeating times: 23, Iteration times: 1
# [0.49019608 0.49019608 0.88235294 0.90196078]
# Repeating times: 24, Iteration times: 1
# [0.76470588 0.56862745 0.56862745 0.56862745]
# Repeating times: 25, Iteration times: 1
# [0.50980392 0.50980392 0.50980392 0.96078431]
# Repeating times: 26, Iteration times: 1
# [0.60784314 0.56862745 0.56862745 0.8627451 ]
# Repeating times: 27, Iteration times: 1
# [0.68627451 0.62745098 0.49019608 0.62745098]
# Repeating times: 28, Iteration times: 1
# [0.76470588 0.54901961 0.54901961 0.54901961]
# Repeating times: 29, Iteration times: 1
# [1.         1.         0.47058824 0.68627451]
# Repeating times: 30, Iteration times: 1
# [0.64705882 1.         0.56862745 0.49019608]
# Repeating times: 31, Iteration times: 1
# [0.62745098 0.62745098 0.62745098 0.62745098]
# Repeating times: 32, Iteration times: 1
# [0.78431373 0.96078431 0.66666667 0.52941176]
# Repeating times: 33, Iteration times: 1
# [0.80392157 0.49019608 0.54901961 0.49019608]
# Repeating times: 34, Iteration times: 1
# [0.50980392 0.50980392 0.60784314 0.8627451 ]
# Repeating times: 35, Iteration times: 1
# [0.58823529 0.74509804 0.78431373 0.56862745]
# Repeating times: 36, Iteration times: 1
# [0.62745098 0.66666667 0.88235294 0.7254902 ]
# Repeating times: 37, Iteration times: 1
# [0.49019608 0.96078431 0.68627451 0.68627451]
# Repeating times: 38, Iteration times: 1
# [0.56862745 0.56862745 0.56862745 0.56862745]
# Repeating times: 39, Iteration times: 1
# [0.60784314 0.94117647 0.68627451 0.96078431]
# Repeating times: 40, Iteration times: 1
# [0.52941176 0.92156863 1.         0.52941176]
# Repeating times: 41, Iteration times: 1
# [0.80392157 0.84313725 0.62745098 0.56862745]
# Repeating times: 42, Iteration times: 1
# [0.62745098 0.50980392 0.50980392 0.68627451]
# Repeating times: 43, Iteration times: 1
# [0.56862745 0.96078431 0.56862745 0.56862745]
# Repeating times: 44, Iteration times: 1
# [0.49019608 0.49019608 0.54901961 0.92156863]
# Repeating times: 45, Iteration times: 1
# [0.64705882 0.80392157 0.64705882 0.64705882]
# Repeating times: 46, Iteration times: 1
# [1.         0.84313725 0.49019608 0.52941176]
# Repeating times: 47, Iteration times: 1
# [0.8627451  0.88235294 0.88235294 0.80392157]
# Repeating times: 48, Iteration times: 1
# [0.90196078 0.90196078 0.92156863 0.94117647]
# Repeating times: 49, Iteration times: 1
# [0.82352941 0.64705882 0.60784314 0.80392157]
# Repeating times: 50, Iteration times: 1
# [0.84313725 0.50980392 0.50980392 0.50980392]
# Repeating times: 51, Iteration times: 1
# [0.70588235 0.88235294 0.94117647 0.78431373]
# Repeating times: 52, Iteration times: 1
# [0.50980392 0.50980392 0.52941176 0.76470588]
# Repeating times: 53, Iteration times: 1
# [0.74509804 0.45098039 0.62745098 0.66666667]
# Repeating times: 54, Iteration times: 1
# [0.74509804 0.62745098 0.52941176 0.52941176]
# Repeating times: 55, Iteration times: 1
# [0.92156863 0.54901961 0.54901961 0.94117647]
# Repeating times: 56, Iteration times: 1
# [0.74509804 0.62745098 0.62745098 0.92156863]
# Repeating times: 57, Iteration times: 1
# [0.82352941 1.         0.50980392 0.50980392]
# Repeating times: 58, Iteration times: 1
# [0.62745098 0.66666667 0.68627451 0.62745098]
# Repeating times: 59, Iteration times: 1
# [0.50980392 0.50980392 0.64705882 1.        ]
# Repeating times: 60, Iteration times: 1
# [0.54901961 0.94117647 0.88235294 0.54901961]
# Repeating times: 61, Iteration times: 1
# [0.64705882 0.49019608 0.52941176 1.        ]
# Repeating times: 62, Iteration times: 1
# [0.49019608 0.66666667 0.49019608 0.49019608]
# Repeating times: 63, Iteration times: 1
# [0.66666667 0.66666667 0.49019608 0.49019608]
# Repeating times: 64, Iteration times: 1
# [0.64705882 0.64705882 0.74509804 0.92156863]
# Repeating times: 65, Iteration times: 1
# [0.92156863 0.54901961 0.88235294 0.54901961]
# Repeating times: 66, Iteration times: 1
# [0.58823529 0.62745098 0.68627451 0.68627451]
# Repeating times: 67, Iteration times: 1
# [0.98039216 0.54901961 0.84313725 0.54901961]
# Repeating times: 68, Iteration times: 1
# [0.60784314 0.76470588 0.56862745 0.92156863]
# Repeating times: 69, Iteration times: 1
# [0.54901961 0.54901961 1.         0.39215686]
# Repeating times: 70, Iteration times: 1
# [0.52941176 0.52941176 0.96078431 0.52941176]
# Repeating times: 71, Iteration times: 1
# [0.54901961 0.54901961 0.54901961 0.54901961]
# Repeating times: 72, Iteration times: 1
# [0.47058824 0.47058824 0.82352941 0.62745098]
# Repeating times: 73, Iteration times: 1
# [0.47058824 0.98039216 0.92156863 0.64705882]
# Repeating times: 74, Iteration times: 1
# [0.62745098 0.82352941 0.58823529 0.54901961]
# Repeating times: 75, Iteration times: 1
# [0.68627451 0.68627451 0.68627451 0.96078431]
# Repeating times: 76, Iteration times: 1
# [0.54901961 0.62745098 0.54901961 0.80392157]
# Repeating times: 77, Iteration times: 1
# [0.58823529 0.64705882 0.96078431 0.76470588]
# Repeating times: 78, Iteration times: 1
# [0.50980392 0.88235294 0.64705882 0.50980392]
# Repeating times: 79, Iteration times: 1
# [0.84313725 0.88235294 0.52941176 0.56862745]
# Repeating times: 80, Iteration times: 1
# [0.7254902  0.47058824 0.64705882 0.7254902 ]
# Repeating times: 81, Iteration times: 1
# [0.56862745 0.47058824 0.47058824 0.58823529]
# Repeating times: 82, Iteration times: 1
# [0.50980392 0.74509804 0.90196078 0.98039216]
# Repeating times: 83, Iteration times: 1
# [0.52941176 0.52941176 0.96078431 0.52941176]
# Repeating times: 84, Iteration times: 1
# [0.50980392 1.         0.66666667 0.50980392]
# Repeating times: 85, Iteration times: 1
# [0.8627451  0.58823529 0.58823529 0.80392157]
# Repeating times: 86, Iteration times: 1
# [0.7254902  0.62745098 0.80392157 0.98039216]
# Repeating times: 87, Iteration times: 1
# [0.78431373 0.76470588 0.52941176 0.50980392]
# Repeating times: 88, Iteration times: 1
# [0.84313725 0.56862745 0.8627451  0.92156863]
# Repeating times: 89, Iteration times: 1
# [0.90196078 0.45098039 0.68627451 0.96078431]
# Repeating times: 90, Iteration times: 1
# [0.54901961 0.98039216 0.54901961 0.54901961]
# Repeating times: 91, Iteration times: 1
# [0.74509804 0.45098039 0.80392157 0.92156863]
# Repeating times: 92, Iteration times: 1
# [0.49019608 0.58823529 0.49019608 0.96078431]
# Repeating times: 93, Iteration times: 1
# [0.7254902  0.96078431 0.84313725 0.45098039]
# Repeating times: 94, Iteration times: 1
# [0.70588235 0.78431373 0.66666667 0.50980392]
# Repeating times: 95, Iteration times: 1
# [0.60784314 0.52941176 1.         0.82352941]
# Repeating times: 96, Iteration times: 1
# [0.66666667 0.92156863 0.70588235 0.58823529]
# Repeating times: 97, Iteration times: 1
# [0.49019608 0.49019608 0.78431373 0.82352941]
# Repeating times: 98, Iteration times: 1
# [0.88235294 0.56862745 0.94117647 0.7254902 ]
# Repeating times: 99, Iteration times: 1
# [0.56862745 0.56862745 0.56862745 0.84313725]
# Repeating times: 0, Iteration times: 2
# [0.80392157 0.60784314 0.66666667 0.76470588]
# Repeating times: 1, Iteration times: 2
# [0.47058824 0.60784314 0.47058824 0.47058824]
# Repeating times: 2, Iteration times: 2
# [0.52941176 0.52941176 0.98039216 0.64705882]
# Repeating times: 3, Iteration times: 2
# [0.56862745 0.76470588 0.62745098 0.66666667]
# Repeating times: 4, Iteration times: 2
# [0.50980392 0.70588235 0.60784314 0.92156863]
# Repeating times: 5, Iteration times: 2
# [0.92156863 0.60784314 0.7254902  0.90196078]
# Repeating times: 6, Iteration times: 2
# [0.58823529 0.90196078 0.68627451 0.54901961]
# Repeating times: 7, Iteration times: 2
# [0.50980392 0.50980392 0.78431373 0.74509804]
# Repeating times: 8, Iteration times: 2
# [0.8627451  0.47058824 0.47058824 0.98039216]
# Repeating times: 9, Iteration times: 2
# [0.50980392 0.50980392 0.50980392 0.50980392]
# Repeating times: 10, Iteration times: 2
# [0.8627451  0.56862745 0.56862745 0.56862745]
# Repeating times: 11, Iteration times: 2
# [0.60784314 0.60784314 0.78431373 0.60784314]
# Repeating times: 12, Iteration times: 2
# [0.80392157 0.56862745 0.62745098 0.66666667]
# Repeating times: 13, Iteration times: 2
# [0.58823529 0.66666667 0.66666667 0.70588235]
# Repeating times: 14, Iteration times: 2
# [0.60784314 0.7254902  0.45098039 0.64705882]
# Repeating times: 15, Iteration times: 2
# [0.58823529 0.88235294 0.8627451  0.84313725]
# Repeating times: 16, Iteration times: 2
# [0.98039216 0.98039216 0.68627451 0.92156863]
# Repeating times: 17, Iteration times: 2
# [0.84313725 0.92156863 0.62745098 0.52941176]
# Repeating times: 18, Iteration times: 2
# [0.88235294 0.64705882 0.8627451  0.88235294]
# Repeating times: 19, Iteration times: 2
# [0.62745098 0.98039216 0.76470588 0.82352941]
# Repeating times: 20, Iteration times: 2
# [0.54901961 0.84313725 0.94117647 0.54901961]
# Repeating times: 21, Iteration times: 2
# [0.88235294 0.47058824 0.88235294 0.47058824]
# Repeating times: 22, Iteration times: 2
# [0.49019608 0.49019608 0.49019608 0.66666667]
# Repeating times: 23, Iteration times: 2
# [0.96078431 0.78431373 0.78431373 0.68627451]
# Repeating times: 24, Iteration times: 2
# [0.49019608 0.98039216 0.64705882 0.64705882]
# Repeating times: 25, Iteration times: 2
# [0.52941176 0.52941176 0.94117647 1.        ]
# Repeating times: 26, Iteration times: 2
# [0.98039216 0.60784314 0.74509804 0.60784314]
# Repeating times: 27, Iteration times: 2
# [0.96078431 0.88235294 0.82352941 0.52941176]
# Repeating times: 28, Iteration times: 2
# [0.70588235 0.50980392 0.96078431 0.43137255]
# Repeating times: 29, Iteration times: 2
# [0.64705882 0.70588235 0.92156863 0.64705882]
# Repeating times: 30, Iteration times: 2
# [0.52941176 0.52941176 0.52941176 0.52941176]
# Repeating times: 31, Iteration times: 2
# [0.54901961 0.50980392 0.62745098 0.50980392]
# Repeating times: 32, Iteration times: 2
# [0.90196078 0.90196078 1.         0.84313725]
# Repeating times: 33, Iteration times: 2
# [0.94117647 0.50980392 0.50980392 0.94117647]
# Repeating times: 34, Iteration times: 2
# [0.56862745 0.56862745 0.56862745 0.56862745]
# Repeating times: 35, Iteration times: 2
# [0.56862745 0.94117647 0.70588235 0.56862745]
# Repeating times: 36, Iteration times: 2
# [0.56862745 0.56862745 0.62745098 0.94117647]
# Repeating times: 37, Iteration times: 2
# [0.52941176 0.60784314 0.56862745 0.70588235]
# Repeating times: 38, Iteration times: 2
# [0.54901961 0.66666667 0.60784314 0.90196078]
# Repeating times: 39, Iteration times: 2
# [0.52941176 0.94117647 0.45098039 0.49019608]
# Repeating times: 40, Iteration times: 2
# [0.90196078 0.68627451 0.52941176 0.94117647]
# Repeating times: 41, Iteration times: 2
# [0.74509804 0.82352941 0.54901961 0.54901961]
# Repeating times: 42, Iteration times: 2
# [0.98039216 0.7254902  0.94117647 0.66666667]
# Repeating times: 43, Iteration times: 2
# [0.52941176 0.60784314 0.58823529 0.58823529]
# Repeating times: 44, Iteration times: 2
# [0.47058824 0.47058824 0.47058824 0.70588235]
# Repeating times: 45, Iteration times: 2
# [0.74509804 0.58823529 0.58823529 0.74509804]
# Repeating times: 46, Iteration times: 2
# [0.84313725 0.76470588 0.74509804 0.80392157]
# Repeating times: 47, Iteration times: 2
# [0.45098039 0.45098039 0.45098039 0.58823529]
# Repeating times: 48, Iteration times: 2
# [0.56862745 0.68627451 0.68627451 0.41176471]
# Repeating times: 49, Iteration times: 2
# [0.52941176 0.52941176 0.52941176 0.52941176]
# Repeating times: 50, Iteration times: 2
# [0.84313725 0.80392157 0.47058824 0.94117647]
# Repeating times: 51, Iteration times: 2
# [1.         0.54901961 0.96078431 0.68627451]
# Repeating times: 52, Iteration times: 2
# [0.56862745 0.92156863 0.76470588 0.96078431]
# Repeating times: 53, Iteration times: 2
# [0.7254902  0.64705882 0.66666667 0.68627451]
# Repeating times: 54, Iteration times: 2
# [0.92156863 0.88235294 0.68627451 0.50980392]
# Repeating times: 55, Iteration times: 2
# [0.64705882 0.64705882 0.74509804 0.64705882]
# Repeating times: 56, Iteration times: 2
# [0.49019608 0.49019608 0.76470588 0.58823529]
# Repeating times: 57, Iteration times: 2
# [0.49019608 0.8627451  0.7254902  0.58823529]
# Repeating times: 58, Iteration times: 2
# [0.52941176 0.88235294 0.80392157 0.52941176]
# Repeating times: 59, Iteration times: 2
# [0.54901961 0.92156863 0.54901961 0.54901961]
# Repeating times: 60, Iteration times: 2
# [0.78431373 0.58823529 0.82352941 0.58823529]
# Repeating times: 61, Iteration times: 2
# [0.50980392 0.74509804 0.84313725 0.50980392]
# Repeating times: 62, Iteration times: 2
# [0.96078431 0.58823529 0.54901961 0.68627451]
# Repeating times: 63, Iteration times: 2
# [0.98039216 0.88235294 0.52941176 0.52941176]
# Repeating times: 64, Iteration times: 2
# [0.64705882 0.80392157 0.94117647 0.8627451 ]
# Repeating times: 65, Iteration times: 2
# [0.98039216 0.54901961 0.54901961 0.54901961]
# Repeating times: 66, Iteration times: 2
# [0.58823529 0.50980392 0.62745098 0.82352941]
# Repeating times: 67, Iteration times: 2
# [0.8627451  0.56862745 0.82352941 0.56862745]
# Repeating times: 68, Iteration times: 2
# [0.62745098 0.66666667 0.66666667 0.88235294]
# Repeating times: 69, Iteration times: 2
# [0.88235294 0.8627451  0.82352941 0.82352941]
# Repeating times: 70, Iteration times: 2
# [0.70588235 0.66666667 0.52941176 0.52941176]
# Repeating times: 71, Iteration times: 2
# [0.58823529 0.82352941 1.         0.58823529]
# Repeating times: 72, Iteration times: 2
# [0.60784314 0.66666667 0.80392157 0.90196078]
# Repeating times: 73, Iteration times: 2
# [0.54901961 0.54901961 0.54901961 0.54901961]
# Repeating times: 74, Iteration times: 2
# [0.7254902  0.52941176 0.70588235 0.52941176]
# Repeating times: 75, Iteration times: 2
# [0.64705882 0.54901961 0.54901961 0.54901961]
# Repeating times: 76, Iteration times: 2
# [0.64705882 0.96078431 0.49019608 0.49019608]
# Repeating times: 77, Iteration times: 2
# [0.82352941 0.64705882 0.92156863 0.76470588]
# Repeating times: 78, Iteration times: 2
# [0.52941176 0.52941176 0.78431373 0.52941176]
# Repeating times: 79, Iteration times: 2
# [0.62745098 0.62745098 0.62745098 0.62745098]
# Repeating times: 80, Iteration times: 2
# [0.64705882 0.56862745 0.70588235 0.94117647]
# Repeating times: 81, Iteration times: 2
# [0.76470588 0.60784314 0.76470588 0.60784314]
# Repeating times: 82, Iteration times: 2
# [0.8627451  0.62745098 0.78431373 0.8627451 ]
# Repeating times: 83, Iteration times: 2
# [0.49019608 0.80392157 0.74509804 0.64705882]
# Repeating times: 84, Iteration times: 2
# [0.66666667 0.90196078 0.8627451  0.66666667]
# Repeating times: 85, Iteration times: 2
# [0.66666667 0.66666667 0.62745098 0.84313725]
# Repeating times: 86, Iteration times: 2
# [0.58823529 0.66666667 0.58823529 0.58823529]
# Repeating times: 87, Iteration times: 2
# [0.50980392 0.50980392 0.76470588 0.70588235]
# Repeating times: 88, Iteration times: 2
# [1.         0.52941176 0.66666667 0.70588235]
# Repeating times: 89, Iteration times: 2
# [0.7254902  0.60784314 0.78431373 0.60784314]
# Repeating times: 90, Iteration times: 2
# [0.74509804 0.92156863 0.56862745 0.50980392]
# Repeating times: 91, Iteration times: 2
# [0.8627451  0.8627451  0.62745098 0.58823529]
# Repeating times: 92, Iteration times: 2
# [1.         0.70588235 0.56862745 0.56862745]
# Repeating times: 93, Iteration times: 2
# [0.96078431 0.7254902  0.62745098 0.62745098]
# Repeating times: 94, Iteration times: 2
# [0.78431373 0.92156863 0.47058824 0.50980392]
# Repeating times: 95, Iteration times: 2
# [0.88235294 0.47058824 0.47058824 0.88235294]
# Repeating times: 96, Iteration times: 2
# [0.62745098 0.84313725 0.62745098 0.62745098]
# Repeating times: 97, Iteration times: 2
# [0.78431373 0.56862745 0.56862745 0.56862745]
# Repeating times: 98, Iteration times: 2
# [0.58823529 0.7254902  0.49019608 0.56862745]
# Repeating times: 99, Iteration times: 2
# [0.70588235 0.54901961 0.76470588 0.84313725]
# Repeating times: 0, Iteration times: 3
# [0.74509804 0.50980392 0.50980392 0.56862745]
# Repeating times: 1, Iteration times: 3
# [0.7254902  0.54901961 0.64705882 0.54901961]
# Repeating times: 2, Iteration times: 3
# [0.58823529 0.58823529 0.62745098 0.84313725]
# Repeating times: 3, Iteration times: 3
# [0.94117647 0.66666667 0.56862745 0.96078431]
# Repeating times: 4, Iteration times: 3
# [0.52941176 0.60784314 0.52941176 0.52941176]
# Repeating times: 5, Iteration times: 3
# [0.52941176 0.56862745 0.52941176 0.52941176]
# Repeating times: 6, Iteration times: 3
# [0.66666667 0.60784314 0.74509804 0.60784314]
# Repeating times: 7, Iteration times: 3
# [0.62745098 0.62745098 0.74509804 0.62745098]
# Repeating times: 8, Iteration times: 3
# [0.78431373 0.54901961 0.8627451  0.76470588]
# Repeating times: 9, Iteration times: 3
# [1.         0.74509804 1.         0.52941176]
# Repeating times: 10, Iteration times: 3
# [0.50980392 0.76470588 0.8627451  0.50980392]
# Repeating times: 11, Iteration times: 3
# [0.84313725 0.78431373 0.54901961 0.94117647]
# Repeating times: 12, Iteration times: 3
# [0.8627451  0.70588235 0.58823529 0.96078431]
# Repeating times: 13, Iteration times: 3
# [0.54901961 0.54901961 0.92156863 0.76470588]
# Repeating times: 14, Iteration times: 3
# [0.82352941 0.62745098 0.70588235 0.82352941]
# Repeating times: 15, Iteration times: 3
# [0.92156863 0.60784314 0.49019608 0.49019608]
# Repeating times: 16, Iteration times: 3
# [0.76470588 0.62745098 0.47058824 0.94117647]
# Repeating times: 17, Iteration times: 3
# [0.8627451  0.62745098 0.62745098 0.84313725]
# Repeating times: 18, Iteration times: 3
# [0.50980392 0.76470588 0.68627451 0.62745098]
# Repeating times: 19, Iteration times: 3
# [0.56862745 0.60784314 0.82352941 0.56862745]
# Repeating times: 20, Iteration times: 3
# [0.88235294 0.66666667 0.68627451 0.68627451]
# Repeating times: 21, Iteration times: 3
# [0.50980392 0.84313725 0.84313725 1.        ]
# Repeating times: 22, Iteration times: 3
# [0.52941176 0.84313725 0.52941176 0.62745098]
# Repeating times: 23, Iteration times: 3
# [0.78431373 0.78431373 0.54901961 0.54901961]
# Repeating times: 24, Iteration times: 3
# [0.52941176 0.52941176 0.70588235 0.98039216]
# Repeating times: 25, Iteration times: 3
# [0.56862745 0.88235294 0.68627451 0.92156863]
# Repeating times: 26, Iteration times: 3
# [0.70588235 0.54901961 0.56862745 0.54901961]
# Repeating times: 27, Iteration times: 3
# [0.54901961 0.68627451 0.54901961 0.54901961]
# Repeating times: 28, Iteration times: 3
# [0.45098039 0.45098039 0.90196078 0.45098039]
# Repeating times: 29, Iteration times: 3
# [0.50980392 0.50980392 0.50980392 0.50980392]
# Repeating times: 30, Iteration times: 3
# [0.56862745 0.54901961 0.84313725 0.68627451]
# Repeating times: 31, Iteration times: 3
# [0.98039216 0.90196078 0.62745098 0.62745098]
# Repeating times: 32, Iteration times: 3
# [0.84313725 0.94117647 0.66666667 0.52941176]
# Repeating times: 33, Iteration times: 3
# [1.         0.66666667 0.76470588 0.98039216]
# Repeating times: 34, Iteration times: 3
# [0.58823529 0.58823529 0.8627451  0.74509804]
# Repeating times: 35, Iteration times: 3
# [0.82352941 0.64705882 0.98039216 0.74509804]
# Repeating times: 36, Iteration times: 3
# [0.50980392 0.8627451  0.50980392 1.        ]
# Repeating times: 37, Iteration times: 3
# [0.58823529 0.58823529 1.         0.88235294]
# Repeating times: 38, Iteration times: 3
# [0.58823529 0.92156863 0.96078431 0.58823529]
# Repeating times: 39, Iteration times: 3
# [0.96078431 0.74509804 0.56862745 0.56862745]
# Repeating times: 40, Iteration times: 3
# [0.54901961 0.96078431 0.76470588 0.64705882]
# Repeating times: 41, Iteration times: 3
# [0.49019608 0.78431373 0.49019608 0.70588235]
# Repeating times: 42, Iteration times: 3
# [0.58823529 1.         0.68627451 0.58823529]
# Repeating times: 43, Iteration times: 3
# [0.54901961 0.54901961 0.92156863 0.74509804]
# Repeating times: 44, Iteration times: 3
# [0.54901961 0.37254902 0.37254902 0.66666667]
# Repeating times: 45, Iteration times: 3
# [0.58823529 0.84313725 0.90196078 0.52941176]
# Repeating times: 46, Iteration times: 3
# [0.96078431 0.68627451 0.68627451 0.68627451]
# Repeating times: 47, Iteration times: 3
# [0.58823529 0.68627451 0.76470588 0.68627451]
# Repeating times: 48, Iteration times: 3
# [0.98039216 0.60784314 0.88235294 0.54901961]
# Repeating times: 49, Iteration times: 3
# [0.47058824 0.58823529 0.47058824 0.94117647]
# Repeating times: 50, Iteration times: 3
# [0.84313725 0.98039216 0.54901961 0.54901961]
# Repeating times: 51, Iteration times: 3
# [0.96078431 0.56862745 0.56862745 0.76470588]
# Repeating times: 52, Iteration times: 3
# [0.50980392 0.94117647 0.50980392 0.50980392]
# Repeating times: 53, Iteration times: 3
# [0.52941176 0.88235294 0.88235294 0.90196078]
# Repeating times: 54, Iteration times: 3
# [0.50980392 0.76470588 0.50980392 0.7254902 ]
# Repeating times: 55, Iteration times: 3
# [0.96078431 0.47058824 0.82352941 0.47058824]
# Repeating times: 56, Iteration times: 3
# [0.54901961 0.60784314 0.76470588 0.80392157]
# Repeating times: 57, Iteration times: 3
# [0.92156863 0.88235294 0.7254902  0.52941176]
# Repeating times: 58, Iteration times: 3
# [0.82352941 0.88235294 0.7254902  0.82352941]
# Repeating times: 59, Iteration times: 3
# [0.56862745 0.78431373 0.56862745 1.        ]
# Repeating times: 60, Iteration times: 3
# [0.70588235 0.52941176 0.52941176 0.96078431]
# Repeating times: 61, Iteration times: 3
# [0.84313725 0.88235294 0.54901961 0.50980392]
# Repeating times: 62, Iteration times: 3
# [0.66666667 0.56862745 0.66666667 0.74509804]
# Repeating times: 63, Iteration times: 3
# [0.80392157 0.80392157 0.62745098 0.62745098]
# Repeating times: 64, Iteration times: 3
# [0.52941176 0.54901961 0.90196078 0.76470588]
# Repeating times: 65, Iteration times: 3
# [0.82352941 0.58823529 0.74509804 0.70588235]
# Repeating times: 66, Iteration times: 3
# [0.58823529 1.         0.98039216 0.58823529]
# Repeating times: 67, Iteration times: 3
# [0.94117647 0.60784314 0.60784314 0.7254902 ]
# Repeating times: 68, Iteration times: 3
# [0.66666667 0.66666667 0.60784314 0.8627451 ]
# Repeating times: 69, Iteration times: 3
# [0.88235294 0.62745098 0.62745098 0.66666667]
# Repeating times: 70, Iteration times: 3
# [0.94117647 0.78431373 0.66666667 0.98039216]
# Repeating times: 71, Iteration times: 3
# [0.62745098 1.         0.54901961 0.54901961]
# Repeating times: 72, Iteration times: 3
# [0.74509804 0.7254902  0.60784314 0.49019608]
# Repeating times: 73, Iteration times: 3
# [0.50980392 0.74509804 0.94117647 1.        ]
# Repeating times: 74, Iteration times: 3
# [0.64705882 0.64705882 0.64705882 0.64705882]
# Repeating times: 75, Iteration times: 3
# [0.50980392 0.78431373 0.84313725 0.50980392]
# Repeating times: 76, Iteration times: 3
# [0.80392157 0.54901961 0.54901961 0.54901961]
# Repeating times: 77, Iteration times: 3
# [0.52941176 0.52941176 0.66666667 0.52941176]
# Repeating times: 78, Iteration times: 3
# [0.52941176 0.52941176 0.52941176 0.98039216]
# Repeating times: 79, Iteration times: 3
# [0.56862745 0.76470588 0.56862745 0.68627451]
# Repeating times: 80, Iteration times: 3
# [0.76470588 0.50980392 0.60784314 0.94117647]
# Repeating times: 81, Iteration times: 3
# [1.         0.74509804 0.49019608 0.88235294]
# Repeating times: 82, Iteration times: 3
# [0.56862745 0.56862745 0.56862745 0.94117647]
# Repeating times: 83, Iteration times: 3
# [0.49019608 0.94117647 0.49019608 0.90196078]
# Repeating times: 84, Iteration times: 3
# [0.47058824 0.68627451 1.         0.47058824]
# Repeating times: 85, Iteration times: 3
# [0.82352941 0.56862745 0.96078431 0.76470588]
# Repeating times: 86, Iteration times: 3
# [0.62745098 0.62745098 0.62745098 0.62745098]
# Repeating times: 87, Iteration times: 3
# [0.76470588 0.64705882 0.98039216 0.70588235]
# Repeating times: 88, Iteration times: 3
# [0.94117647 0.54901961 0.54901961 0.62745098]
# Repeating times: 89, Iteration times: 3
# [0.60784314 0.64705882 0.60784314 0.54901961]
# Repeating times: 90, Iteration times: 3
# [0.58823529 0.45098039 0.58823529 0.8627451 ]
# Repeating times: 91, Iteration times: 3
# [0.64705882 0.60784314 0.47058824 0.47058824]
# Repeating times: 92, Iteration times: 3
# [0.8627451  0.50980392 0.50980392 0.50980392]
# Repeating times: 93, Iteration times: 3
# [0.94117647 0.60784314 0.56862745 0.56862745]
# Repeating times: 94, Iteration times: 3
# [0.60784314 0.60784314 0.60784314 0.60784314]
# Repeating times: 95, Iteration times: 3
# [0.54901961 0.64705882 1.         0.62745098]
# Repeating times: 96, Iteration times: 3
# [0.45098039 0.88235294 0.68627451 0.54901961]
# Repeating times: 97, Iteration times: 3
# [0.70588235 0.54901961 0.62745098 0.62745098]
# Repeating times: 98, Iteration times: 3
# [0.52941176 0.52941176 0.76470588 0.82352941]
# Repeating times: 99, Iteration times: 3
# [0.70588235 0.64705882 0.64705882 0.94117647]
# Repeating times: 0, Iteration times: 4
# [1.         0.96078431 0.68627451 0.88235294]
# Repeating times: 1, Iteration times: 4
# [0.76470588 0.84313725 0.50980392 0.58823529]
# Repeating times: 2, Iteration times: 4
# [0.7254902  0.58823529 0.84313725 0.90196078]
# Repeating times: 3, Iteration times: 4
# [0.7254902  0.84313725 0.58823529 1.        ]
# Repeating times: 4, Iteration times: 4
# [0.96078431 0.82352941 0.54901961 0.82352941]
# Repeating times: 5, Iteration times: 4
# [0.98039216 0.8627451  0.60784314 0.58823529]
# Repeating times: 6, Iteration times: 4
# [0.68627451 0.88235294 0.90196078 0.64705882]
# Repeating times: 7, Iteration times: 4
# [0.68627451 0.8627451  0.68627451 0.88235294]
# Repeating times: 8, Iteration times: 4
# [0.60784314 0.60784314 0.60784314 0.84313725]
# Repeating times: 9, Iteration times: 4
# [0.66666667 1.         0.52941176 0.70588235]
# Repeating times: 10, Iteration times: 4
# [0.64705882 0.52941176 0.64705882 0.94117647]
# Repeating times: 11, Iteration times: 4
# [0.58823529 0.70588235 0.58823529 0.8627451 ]
# Repeating times: 12, Iteration times: 4
# [0.60784314 0.64705882 0.7254902  0.98039216]
# Repeating times: 13, Iteration times: 4
# [0.8627451  0.50980392 0.70588235 0.50980392]
# Repeating times: 14, Iteration times: 4
# [0.49019608 0.98039216 0.49019608 0.49019608]
# Repeating times: 15, Iteration times: 4
# [0.64705882 0.88235294 0.82352941 0.94117647]
# Repeating times: 16, Iteration times: 4
# [0.90196078 0.58823529 0.78431373 0.96078431]
# Repeating times: 17, Iteration times: 4
# [0.64705882 0.76470588 0.64705882 0.80392157]
# Repeating times: 18, Iteration times: 4
# [0.94117647 0.74509804 0.56862745 0.56862745]
# Repeating times: 19, Iteration times: 4
# [0.90196078 0.50980392 0.50980392 0.68627451]
# Repeating times: 20, Iteration times: 4
# [0.54901961 0.66666667 0.54901961 0.78431373]
# Repeating times: 21, Iteration times: 4
# [0.96078431 0.94117647 0.52941176 0.84313725]
# Repeating times: 22, Iteration times: 4
# [0.80392157 0.68627451 0.68627451 0.68627451]
# Repeating times: 23, Iteration times: 4
# [0.90196078 0.58823529 0.76470588 0.58823529]
# Repeating times: 24, Iteration times: 4
# [0.58823529 0.58823529 1.         0.98039216]
# Repeating times: 25, Iteration times: 4
# [0.78431373 0.62745098 0.62745098 0.62745098]
# Repeating times: 26, Iteration times: 4
# [0.50980392 0.90196078 0.50980392 0.74509804]
# Repeating times: 27, Iteration times: 4
# [0.84313725 0.56862745 0.7254902  0.56862745]
# Repeating times: 28, Iteration times: 4
# [0.84313725 0.84313725 0.74509804 0.62745098]
# Repeating times: 29, Iteration times: 4
# [0.78431373 0.92156863 0.64705882 0.64705882]
# Repeating times: 30, Iteration times: 4
# [0.78431373 0.54901961 0.88235294 0.54901961]
# Repeating times: 31, Iteration times: 4
# [0.8627451  0.68627451 0.60784314 0.70588235]
# Repeating times: 32, Iteration times: 4
# [0.56862745 0.52941176 0.52941176 0.52941176]
# Repeating times: 33, Iteration times: 4
# [0.49019608 0.49019608 0.49019608 0.49019608]
# Repeating times: 34, Iteration times: 4
# [0.54901961 0.64705882 0.84313725 0.49019608]
# Repeating times: 35, Iteration times: 4
# [0.52941176 0.52941176 0.74509804 0.52941176]
# Repeating times: 36, Iteration times: 4
# [0.54901961 0.54901961 0.54901961 0.54901961]
# Repeating times: 37, Iteration times: 4
# [0.60784314 0.68627451 0.60784314 0.60784314]
# Repeating times: 38, Iteration times: 4
# [0.52941176 0.64705882 0.64705882 0.52941176]
# Repeating times: 39, Iteration times: 4
# [0.52941176 0.8627451  0.8627451  0.64705882]
# Repeating times: 40, Iteration times: 4
# [0.96078431 0.70588235 0.62745098 0.7254902 ]
# Repeating times: 41, Iteration times: 4
# [0.47058824 0.92156863 0.76470588 0.47058824]
# Repeating times: 42, Iteration times: 4
# [0.60784314 0.88235294 0.96078431 0.74509804]
# Repeating times: 43, Iteration times: 4
# [0.8627451  0.58823529 0.58823529 0.92156863]
# Repeating times: 44, Iteration times: 4
# [0.78431373 0.88235294 0.52941176 0.52941176]
# Repeating times: 45, Iteration times: 4
# [0.54901961 0.80392157 1.         0.78431373]
# Repeating times: 46, Iteration times: 4
# [0.94117647 0.62745098 0.62745098 0.84313725]
# Repeating times: 47, Iteration times: 4
# [0.98039216 0.64705882 0.7254902  0.64705882]
# Repeating times: 48, Iteration times: 4
# [0.56862745 0.56862745 0.98039216 0.78431373]
# Repeating times: 49, Iteration times: 4
# [0.58823529 0.7254902  0.88235294 0.58823529]
# Repeating times: 50, Iteration times: 4
# [0.84313725 0.94117647 0.76470588 0.92156863]
# Repeating times: 51, Iteration times: 4
# [0.62745098 0.62745098 1.         0.70588235]
# Repeating times: 52, Iteration times: 4
# [0.54901961 0.70588235 0.54901961 0.54901961]
# Repeating times: 53, Iteration times: 4
# [0.52941176 0.76470588 0.52941176 0.50980392]
# Repeating times: 54, Iteration times: 4
# [0.52941176 0.92156863 0.52941176 0.76470588]
# Repeating times: 55, Iteration times: 4
# [0.92156863 0.82352941 0.64705882 0.88235294]
# Repeating times: 56, Iteration times: 4
# [0.78431373 0.54901961 0.66666667 0.78431373]
# Repeating times: 57, Iteration times: 4
# [0.64705882 0.62745098 0.68627451 0.60784314]
# Repeating times: 58, Iteration times: 4
# [0.98039216 0.8627451  0.7254902  0.54901961]
# Repeating times: 59, Iteration times: 4
# [0.68627451 0.58823529 0.58823529 0.58823529]
# Repeating times: 60, Iteration times: 4
# [0.90196078 0.62745098 0.62745098 0.62745098]
# Repeating times: 61, Iteration times: 4
# [0.54901961 0.56862745 0.43137255 0.43137255]
# Repeating times: 62, Iteration times: 4
# [0.52941176 0.52941176 0.66666667 0.52941176]
# Repeating times: 63, Iteration times: 4
# [0.50980392 0.68627451 0.50980392 0.50980392]
# Repeating times: 64, Iteration times: 4
# [0.54901961 0.54901961 0.54901961 0.66666667]
# Repeating times: 65, Iteration times: 4
# [0.60784314 0.60784314 0.64705882 0.96078431]
# Repeating times: 66, Iteration times: 4
# [0.50980392 0.78431373 0.50980392 1.        ]
# Repeating times: 67, Iteration times: 4
# [0.58823529 0.92156863 0.88235294 0.90196078]
# Repeating times: 68, Iteration times: 4
# [0.66666667 0.66666667 0.80392157 0.66666667]
# Repeating times: 69, Iteration times: 4
# [0.96078431 0.88235294 0.56862745 0.56862745]
# Repeating times: 70, Iteration times: 4
# [0.82352941 0.64705882 0.66666667 0.80392157]
# Repeating times: 71, Iteration times: 4
# [0.60784314 0.96078431 1.         0.60784314]
# Repeating times: 72, Iteration times: 4
# [0.68627451 0.88235294 0.8627451  1.        ]
# Repeating times: 73, Iteration times: 4
# [0.54901961 0.54901961 0.54901961 0.54901961]
# Repeating times: 74, Iteration times: 4
# [1.         0.88235294 0.98039216 1.        ]
# Repeating times: 75, Iteration times: 4
# [0.60784314 0.74509804 0.94117647 0.96078431]
# Repeating times: 76, Iteration times: 4
# [0.60784314 0.98039216 0.76470588 0.66666667]
# Repeating times: 77, Iteration times: 4
# [0.80392157 0.68627451 0.7254902  0.58823529]
# Repeating times: 78, Iteration times: 4
# [0.94117647 0.60784314 0.50980392 0.84313725]
# Repeating times: 79, Iteration times: 4
# [0.49019608 0.49019608 0.49019608 0.7254902 ]
# Repeating times: 80, Iteration times: 4
# [0.56862745 0.56862745 0.60784314 0.56862745]
# Repeating times: 81, Iteration times: 4
# [0.76470588 0.68627451 0.76470588 0.94117647]
# Repeating times: 82, Iteration times: 4
# [0.50980392 0.50980392 0.68627451 0.76470588]
# Repeating times: 83, Iteration times: 4
# [0.62745098 0.76470588 0.92156863 0.62745098]
# Repeating times: 84, Iteration times: 4
# [0.66666667 0.47058824 0.47058824 0.78431373]
# Repeating times: 85, Iteration times: 4
# [0.98039216 0.7254902  0.58823529 0.98039216]
# Repeating times: 86, Iteration times: 4
# [0.50980392 0.66666667 0.60784314 0.56862745]
# Repeating times: 87, Iteration times: 4
# [0.88235294 0.52941176 0.98039216 1.        ]
# Repeating times: 88, Iteration times: 4
# [0.64705882 0.52941176 0.8627451  0.82352941]
# Repeating times: 89, Iteration times: 4
# [0.90196078 0.66666667 0.58823529 0.88235294]
# Repeating times: 90, Iteration times: 4
# [0.98039216 0.58823529 0.58823529 0.7254902 ]
# Repeating times: 91, Iteration times: 4
# [0.68627451 0.56862745 0.54901961 0.96078431]
# Repeating times: 92, Iteration times: 4
# [0.7254902  0.54901961 0.56862745 0.7254902 ]
# Repeating times: 93, Iteration times: 4
# [0.45098039 0.68627451 0.45098039 0.60784314]
# Repeating times: 94, Iteration times: 4
# [0.54901961 0.54901961 0.76470588 0.76470588]
# Repeating times: 95, Iteration times: 4
# [0.82352941 0.52941176 0.52941176 0.52941176]
# Repeating times: 96, Iteration times: 4
# [0.80392157 0.47058824 0.47058824 0.47058824]
# Repeating times: 97, Iteration times: 4
# [0.98039216 0.60784314 0.49019608 0.49019608]
# Repeating times: 98, Iteration times: 4
# [0.98039216 0.82352941 0.62745098 0.50980392]
# Repeating times: 99, Iteration times: 4
# [0.54901961 0.90196078 0.54901961 0.56862745]
# Repeating times: 0, Iteration times: 5
# [0.47058824 0.96078431 0.47058824 0.94117647]
# Repeating times: 1, Iteration times: 5
# [0.76470588 0.76470588 0.78431373 0.54901961]
# Repeating times: 2, Iteration times: 5
# [0.82352941 0.98039216 1.         0.8627451 ]
# Repeating times: 3, Iteration times: 5
# [0.66666667 0.66666667 0.66666667 0.98039216]
# Repeating times: 4, Iteration times: 5
# [0.58823529 0.47058824 0.98039216 0.47058824]
# Repeating times: 5, Iteration times: 5
# [0.56862745 0.96078431 0.56862745 0.56862745]
# Repeating times: 6, Iteration times: 5
# [0.80392157 0.49019608 0.94117647 0.49019608]
# Repeating times: 7, Iteration times: 5
# [0.84313725 0.58823529 0.80392157 0.76470588]
# Repeating times: 8, Iteration times: 5
# [0.60784314 0.60784314 0.98039216 0.60784314]
# Repeating times: 9, Iteration times: 5
# [0.58823529 0.76470588 0.52941176 0.52941176]
# Repeating times: 10, Iteration times: 5
# [0.76470588 0.96078431 0.76470588 0.58823529]
# Repeating times: 11, Iteration times: 5
# [0.56862745 0.50980392 0.50980392 0.76470588]
# Repeating times: 12, Iteration times: 5
# [0.60784314 0.60784314 1.         0.60784314]
# Repeating times: 13, Iteration times: 5
# [0.58823529 0.58823529 0.78431373 0.58823529]
# Repeating times: 14, Iteration times: 5
# [0.56862745 0.74509804 0.56862745 0.66666667]
# Repeating times: 15, Iteration times: 5
# [0.90196078 0.96078431 0.78431373 0.64705882]
# Repeating times: 16, Iteration times: 5
# [0.7254902  0.56862745 0.66666667 0.56862745]
# Repeating times: 17, Iteration times: 5
# [0.66666667 0.52941176 0.52941176 0.80392157]
# Repeating times: 18, Iteration times: 5
# [1.         0.50980392 0.84313725 0.7254902 ]
# Repeating times: 19, Iteration times: 5
# [0.66666667 0.52941176 0.52941176 0.52941176]
# Repeating times: 20, Iteration times: 5
# [0.70588235 0.7254902  0.56862745 0.60784314]
# Repeating times: 21, Iteration times: 5
# [0.52941176 0.92156863 0.52941176 0.80392157]
# Repeating times: 22, Iteration times: 5
# [0.92156863 1.         0.96078431 0.8627451 ]
# Repeating times: 23, Iteration times: 5
# [0.56862745 0.56862745 0.84313725 0.60784314]
# Repeating times: 24, Iteration times: 5
# [0.68627451 0.96078431 0.62745098 0.62745098]
# Repeating times: 25, Iteration times: 5
# [0.8627451  0.70588235 0.8627451  0.66666667]
# Repeating times: 26, Iteration times: 5
# [0.74509804 0.64705882 0.74509804 0.52941176]
# Repeating times: 27, Iteration times: 5
# [0.52941176 0.47058824 0.68627451 0.47058824]
# Repeating times: 28, Iteration times: 5
# [0.76470588 0.56862745 0.56862745 0.56862745]
# Repeating times: 29, Iteration times: 5
# [0.52941176 0.52941176 0.8627451  0.52941176]
# Repeating times: 30, Iteration times: 5
# [0.96078431 0.90196078 0.80392157 0.60784314]
# Repeating times: 31, Iteration times: 5
# [0.56862745 0.68627451 0.90196078 0.84313725]
# Repeating times: 32, Iteration times: 5
# [0.60784314 0.74509804 0.60784314 0.80392157]
# Repeating times: 33, Iteration times: 5
# [0.56862745 0.49019608 0.80392157 0.49019608]
# Repeating times: 34, Iteration times: 5
# [0.70588235 0.54901961 0.74509804 0.66666667]
# Repeating times: 35, Iteration times: 5
# [0.8627451  0.56862745 0.7254902  0.90196078]
# Repeating times: 36, Iteration times: 5
# [0.84313725 0.76470588 0.62745098 0.70588235]
# Repeating times: 37, Iteration times: 5
# [0.7254902  0.54901961 0.92156863 0.7254902 ]
# Repeating times: 38, Iteration times: 5
# [0.52941176 0.62745098 0.52941176 0.90196078]
# Repeating times: 39, Iteration times: 5
# [0.64705882 0.60784314 0.50980392 0.84313725]
# Repeating times: 40, Iteration times: 5
# [0.64705882 0.84313725 0.74509804 0.60784314]
# Repeating times: 41, Iteration times: 5
# [0.66666667 0.96078431 0.49019608 0.49019608]
# Repeating times: 42, Iteration times: 5
# [0.52941176 0.66666667 0.52941176 0.52941176]
# Repeating times: 43, Iteration times: 5
# [0.56862745 0.94117647 0.58823529 0.70588235]
# Repeating times: 44, Iteration times: 5
# [0.54901961 0.80392157 0.74509804 0.88235294]
# Repeating times: 45, Iteration times: 5
# [0.66666667 0.66666667 0.66666667 0.66666667]
# Repeating times: 46, Iteration times: 5
# [0.52941176 0.47058824 0.54901961 0.54901961]
# Repeating times: 47, Iteration times: 5
# [0.70588235 1.         0.62745098 0.94117647]
# Repeating times: 48, Iteration times: 5
# [0.60784314 0.52941176 0.52941176 0.52941176]
# Repeating times: 49, Iteration times: 5
# [0.45098039 0.45098039 0.80392157 0.66666667]
# Repeating times: 50, Iteration times: 5
# [0.49019608 0.49019608 0.96078431 0.94117647]
# Repeating times: 51, Iteration times: 5
# [0.56862745 0.76470588 0.98039216 0.56862745]
# Repeating times: 52, Iteration times: 5
# [0.58823529 0.58823529 0.58823529 0.64705882]
# Repeating times: 53, Iteration times: 5
# [0.62745098 0.62745098 0.45098039 0.66666667]
# Repeating times: 54, Iteration times: 5
# [0.60784314 0.98039216 0.60784314 0.60784314]
# Repeating times: 55, Iteration times: 5
# [0.78431373 0.70588235 0.84313725 0.58823529]
# Repeating times: 56, Iteration times: 5
# [0.56862745 1.         0.84313725 0.56862745]
# Repeating times: 57, Iteration times: 5
# [0.94117647 0.50980392 0.50980392 0.66666667]
# Repeating times: 58, Iteration times: 5
# ...
# Repeating times: 16, Iteration times: 98
# [0.56862745 0.56862745 0.56862745 0.56862745]
# Repeating times: 17, Iteration times: 98
# [0.58823529 0.58823529 0.58823529 0.62745098]
# Repeating times: 18, Iteration times: 98
# [0.80392157 0.64705882 0.52941176 0.52941176]
# Repeating times: 19, Iteration times: 98
# [0.94117647 0.98039216 0.70588235 0.49019608]
# Repeating times: 20, Iteration times: 98
# [0.62745098 0.50980392 0.82352941 0.50980392]
# Repeating times: 21, Iteration times: 98
# [0.66666667 0.90196078 0.56862745 0.56862745]
# Repeating times: 22, Iteration times: 98
# [0.64705882 0.76470588 0.49019608 0.8627451 ]
# Repeating times: 23, Iteration times: 98
# [0.92156863 0.56862745 0.62745098 0.56862745]
# Repeating times: 24, Iteration times: 98
# [0.64705882 0.84313725 0.64705882 0.64705882]
# Repeating times: 25, Iteration times: 98
# [0.78431373 0.74509804 0.52941176 0.52941176]
# Repeating times: 26, Iteration times: 98
# [0.90196078 0.66666667 0.90196078 0.90196078]
# Repeating times: 27, Iteration times: 98
# [0.7254902  0.47058824 0.47058824 0.94117647]
# Repeating times: 28, Iteration times: 98
# [0.52941176 0.54901961 0.80392157 0.52941176]
# Repeating times: 29, Iteration times: 98
# [0.80392157 1.         0.49019608 0.66666667]
# Repeating times: 30, Iteration times: 98
# [0.58823529 0.58823529 0.58823529 0.98039216]
# Repeating times: 31, Iteration times: 98
# [0.54901961 0.54901961 0.54901961 0.98039216]
# Repeating times: 32, Iteration times: 98
# [1.         0.56862745 0.7254902  1.        ]
# Repeating times: 33, Iteration times: 98
# [0.66666667 0.78431373 0.56862745 0.84313725]
# Repeating times: 34, Iteration times: 98
# [0.66666667 0.56862745 0.78431373 0.56862745]
# Repeating times: 35, Iteration times: 98
# [0.60784314 0.8627451  0.60784314 0.68627451]
# Repeating times: 36, Iteration times: 98
# [0.80392157 0.80392157 0.7254902  0.7254902 ]
# Repeating times: 37, Iteration times: 98
# [0.68627451 0.62745098 0.90196078 0.8627451 ]
# Repeating times: 38, Iteration times: 98
# [0.58823529 0.76470588 0.84313725 0.82352941]
# Repeating times: 39, Iteration times: 98
# [0.60784314 0.80392157 0.54901961 0.94117647]
# Repeating times: 40, Iteration times: 98
# [0.96078431 0.60784314 0.60784314 0.64705882]
# Repeating times: 41, Iteration times: 98
# [0.88235294 1.         0.60784314 0.74509804]
# Repeating times: 42, Iteration times: 98
# [0.8627451  0.78431373 0.7254902  0.98039216]
# Repeating times: 43, Iteration times: 98
# [0.56862745 0.78431373 0.94117647 0.56862745]
# Repeating times: 44, Iteration times: 98
# [0.98039216 0.70588235 0.98039216 0.92156863]
# Repeating times: 45, Iteration times: 98
# [0.52941176 0.52941176 0.52941176 0.8627451 ]
# Repeating times: 46, Iteration times: 98
# [0.98039216 0.58823529 0.92156863 0.58823529]
# Repeating times: 47, Iteration times: 98
# [0.50980392 0.50980392 0.50980392 0.96078431]
# Repeating times: 48, Iteration times: 98
# [0.68627451 0.62745098 0.70588235 0.88235294]
# Repeating times: 49, Iteration times: 98
# [0.52941176 0.52941176 0.68627451 0.52941176]
# Repeating times: 50, Iteration times: 98
# [0.47058824 0.8627451  0.47058824 0.74509804]
# Repeating times: 51, Iteration times: 98
# [0.82352941 0.82352941 0.90196078 0.50980392]
# Repeating times: 52, Iteration times: 98
# [0.90196078 0.60784314 0.82352941 0.80392157]
# Repeating times: 53, Iteration times: 98
# [0.54901961 0.54901961 0.54901961 0.90196078]
# Repeating times: 54, Iteration times: 98
# [0.56862745 0.80392157 0.56862745 0.56862745]
# Repeating times: 55, Iteration times: 98
# [0.66666667 0.50980392 0.58823529 0.50980392]
# Repeating times: 56, Iteration times: 98
# [0.82352941 0.66666667 0.49019608 0.49019608]
# Repeating times: 57, Iteration times: 98
# [0.56862745 0.56862745 0.98039216 0.56862745]
# Repeating times: 58, Iteration times: 98
# [0.70588235 0.45098039 0.45098039 0.45098039]
# Repeating times: 59, Iteration times: 98
# [0.58823529 0.7254902  0.90196078 0.58823529]
# Repeating times: 60, Iteration times: 98
# [0.60784314 0.45098039 0.45098039 0.70588235]
# Repeating times: 61, Iteration times: 98
# [0.54901961 0.54901961 0.96078431 0.82352941]
# Repeating times: 62, Iteration times: 98
# [0.58823529 0.58823529 0.58823529 0.58823529]
# Repeating times: 63, Iteration times: 98
# [1.         0.54901961 0.82352941 0.82352941]
# Repeating times: 64, Iteration times: 98
# [0.60784314 0.49019608 0.49019608 0.49019608]
# Repeating times: 65, Iteration times: 98
# [0.58823529 0.7254902  0.39215686 0.92156863]
# Repeating times: 66, Iteration times: 98
# [0.92156863 0.62745098 0.80392157 0.64705882]
# Repeating times: 67, Iteration times: 98
# [0.52941176 0.52941176 0.8627451  0.52941176]
# Repeating times: 68, Iteration times: 98
# [0.52941176 0.60784314 0.62745098 0.80392157]
# Repeating times: 69, Iteration times: 98
# [0.82352941 0.64705882 0.60784314 0.60784314]
# Repeating times: 70, Iteration times: 98
# [0.70588235 0.74509804 0.64705882 0.64705882]
# Repeating times: 71, Iteration times: 98
# [0.58823529 0.58823529 0.88235294 0.58823529]
# Repeating times: 72, Iteration times: 98
# [0.88235294 0.7254902  0.52941176 0.52941176]
# Repeating times: 73, Iteration times: 98
# [0.68627451 0.56862745 0.56862745 0.56862745]
# Repeating times: 74, Iteration times: 98
# [0.98039216 0.50980392 0.82352941 0.60784314]
# Repeating times: 75, Iteration times: 98
# [0.60784314 0.60784314 0.70588235 0.82352941]
# Repeating times: 76, Iteration times: 98
# [0.62745098 0.60784314 0.60784314 0.74509804]
# Repeating times: 77, Iteration times: 98
# [0.74509804 0.94117647 0.66666667 0.74509804]
# Repeating times: 78, Iteration times: 98
# [0.80392157 0.62745098 0.8627451  1.        ]
# Repeating times: 79, Iteration times: 98
# [0.76470588 0.98039216 0.56862745 0.56862745]
# Repeating times: 80, Iteration times: 98
# [0.94117647 0.52941176 0.8627451  0.76470588]
# Repeating times: 81, Iteration times: 98
# [0.66666667 0.56862745 0.56862745 0.56862745]
# Repeating times: 82, Iteration times: 98
# [0.58823529 0.58823529 0.78431373 0.8627451 ]
# Repeating times: 83, Iteration times: 98
# [0.58823529 0.74509804 0.52941176 0.52941176]
# Repeating times: 84, Iteration times: 98
# [0.82352941 0.7254902  0.74509804 0.78431373]
# Repeating times: 85, Iteration times: 98
# [0.94117647 0.82352941 0.56862745 0.56862745]
# Repeating times: 86, Iteration times: 98
# [0.62745098 0.52941176 1.         0.60784314]
# Repeating times: 87, Iteration times: 98
# [0.49019608 0.49019608 1.         0.49019608]
# Repeating times: 88, Iteration times: 98
# [0.76470588 1.         0.7254902  0.58823529]
# Repeating times: 89, Iteration times: 98
# [0.7254902  0.56862745 0.45098039 0.94117647]
# Repeating times: 90, Iteration times: 98
# [0.78431373 0.78431373 0.54901961 0.76470588]
# Repeating times: 91, Iteration times: 98
# [0.82352941 0.66666667 0.94117647 0.52941176]
# Repeating times: 92, Iteration times: 98
# [0.56862745 0.64705882 0.56862745 0.56862745]
# Repeating times: 93, Iteration times: 98
# [0.90196078 0.54901961 0.94117647 0.62745098]
# Repeating times: 94, Iteration times: 98
# [0.56862745 0.92156863 0.56862745 0.56862745]
# Repeating times: 95, Iteration times: 98
# [0.58823529 0.58823529 0.98039216 0.84313725]
# Repeating times: 96, Iteration times: 98
# [0.82352941 0.54901961 0.80392157 0.54901961]
# Repeating times: 97, Iteration times: 98
# [0.70588235 0.66666667 0.84313725 1.        ]
# Repeating times: 98, Iteration times: 98
# [0.98039216 0.60784314 0.98039216 0.52941176]
# Repeating times: 99, Iteration times: 98
# [0.96078431 0.54901961 0.54901961 0.54901961]
# Repeating times: 0, Iteration times: 99
# [0.7254902  0.54901961 0.84313725 0.54901961]
# Repeating times: 1, Iteration times: 99
# [0.68627451 0.94117647 0.96078431 0.66666667]
# Repeating times: 2, Iteration times: 99
# [0.45098039 0.82352941 0.66666667 0.78431373]
# Repeating times: 3, Iteration times: 99
# [0.96078431 0.58823529 0.66666667 0.49019608]
# Repeating times: 4, Iteration times: 99
# [0.60784314 0.60784314 0.60784314 0.78431373]
# Repeating times: 5, Iteration times: 99
# [0.94117647 0.56862745 0.82352941 0.56862745]
# Repeating times: 6, Iteration times: 99
# [0.56862745 0.78431373 0.56862745 0.84313725]
# Repeating times: 7, Iteration times: 99
# [0.98039216 0.50980392 0.50980392 0.50980392]
# Repeating times: 8, Iteration times: 99
# [0.49019608 0.60784314 0.49019608 0.88235294]
# Repeating times: 9, Iteration times: 99
# [0.47058824 0.47058824 0.47058824 0.82352941]
# Repeating times: 10, Iteration times: 99
# [0.50980392 1.         0.78431373 0.50980392]
# Repeating times: 11, Iteration times: 99
# [0.49019608 0.49019608 0.49019608 0.7254902 ]
# Repeating times: 12, Iteration times: 99
# [0.50980392 0.94117647 0.82352941 0.50980392]
# Repeating times: 13, Iteration times: 99
# [0.64705882 0.80392157 0.54901961 0.64705882]
# Repeating times: 14, Iteration times: 99
# [0.50980392 0.76470588 0.50980392 0.96078431]
# Repeating times: 15, Iteration times: 99
# [0.82352941 0.50980392 0.66666667 0.50980392]
# Repeating times: 16, Iteration times: 99
# [0.7254902  0.58823529 0.58823529 0.96078431]
# Repeating times: 17, Iteration times: 99
# [0.76470588 0.49019608 0.74509804 0.58823529]
# Repeating times: 18, Iteration times: 99
# [0.50980392 0.66666667 0.50980392 0.50980392]
# Repeating times: 19, Iteration times: 99
# [0.78431373 0.66666667 0.60784314 0.74509804]
# Repeating times: 20, Iteration times: 99
# [0.94117647 0.90196078 0.82352941 0.54901961]
# Repeating times: 21, Iteration times: 99
# [0.56862745 0.56862745 0.88235294 0.56862745]
# Repeating times: 22, Iteration times: 99
# [0.60784314 0.60784314 0.60784314 0.74509804]
# Repeating times: 23, Iteration times: 99
# [0.92156863 0.64705882 0.78431373 0.43137255]
# Repeating times: 24, Iteration times: 99
# [0.52941176 0.64705882 0.52941176 0.90196078]
# Repeating times: 25, Iteration times: 99
# [0.66666667 0.94117647 0.92156863 0.66666667]
# Repeating times: 26, Iteration times: 99
# [0.60784314 0.60784314 0.74509804 0.60784314]
# Repeating times: 27, Iteration times: 99
# [0.54901961 0.54901961 0.54901961 0.82352941]
# Repeating times: 28, Iteration times: 99
# [0.56862745 0.80392157 0.56862745 1.        ]
# Repeating times: 29, Iteration times: 99
# [0.58823529 0.96078431 0.7254902  0.88235294]
# Repeating times: 30, Iteration times: 99
# [0.8627451  0.60784314 0.8627451  0.60784314]
# Repeating times: 31, Iteration times: 99
# [0.80392157 0.78431373 0.56862745 0.90196078]
# Repeating times: 32, Iteration times: 99
# [0.60784314 0.60784314 1.         0.60784314]
# Repeating times: 33, Iteration times: 99
# [0.92156863 0.74509804 0.50980392 0.58823529]
# Repeating times: 34, Iteration times: 99
# [0.56862745 0.56862745 0.56862745 0.70588235]
# Repeating times: 35, Iteration times: 99
# [0.74509804 0.54901961 0.54901961 0.54901961]
# Repeating times: 36, Iteration times: 99
# [0.58823529 0.70588235 0.45098039 0.54901961]
# Repeating times: 37, Iteration times: 99
# [0.74509804 0.92156863 0.64705882 0.78431373]
# Repeating times: 38, Iteration times: 99
# [0.8627451  0.64705882 0.80392157 0.96078431]
# Repeating times: 39, Iteration times: 99
# [0.64705882 0.64705882 0.64705882 0.64705882]
# Repeating times: 40, Iteration times: 99
# [0.66666667 0.62745098 0.80392157 0.78431373]
# Repeating times: 41, Iteration times: 99
# [0.50980392 0.50980392 0.82352941 0.94117647]
# Repeating times: 42, Iteration times: 99
# [0.7254902  0.52941176 0.66666667 0.52941176]
# Repeating times: 43, Iteration times: 99
# [0.54901961 0.7254902  0.82352941 0.54901961]
# Repeating times: 44, Iteration times: 99
# [0.62745098 0.74509804 0.70588235 0.62745098]
# Repeating times: 45, Iteration times: 99
# [0.60784314 0.60784314 0.49019608 0.90196078]
# Repeating times: 46, Iteration times: 99
# [0.60784314 0.60784314 0.60784314 0.50980392]
# Repeating times: 47, Iteration times: 99
# [0.54901961 1.         0.47058824 0.47058824]
# Repeating times: 48, Iteration times: 99
# [0.58823529 0.76470588 0.58823529 0.66666667]
# Repeating times: 49, Iteration times: 99
# [0.49019608 0.49019608 0.94117647 0.94117647]
# Repeating times: 50, Iteration times: 99
# [0.52941176 0.56862745 1.         0.80392157]
# Repeating times: 51, Iteration times: 99
# [0.54901961 0.98039216 0.74509804 0.54901961]
# Repeating times: 52, Iteration times: 99
# [0.76470588 0.88235294 0.90196078 0.56862745]
# Repeating times: 53, Iteration times: 99
# [0.64705882 0.64705882 0.98039216 0.68627451]
# Repeating times: 54, Iteration times: 99
# [0.92156863 0.66666667 0.58823529 0.60784314]
# Repeating times: 55, Iteration times: 99
# [0.78431373 0.74509804 0.94117647 0.56862745]
# Repeating times: 56, Iteration times: 99
# [0.56862745 0.54901961 0.54901961 0.84313725]
# Repeating times: 57, Iteration times: 99
# [0.80392157 0.52941176 0.90196078 0.8627451 ]
# Repeating times: 58, Iteration times: 99
# [0.70588235 0.64705882 0.49019608 0.49019608]
# Repeating times: 59, Iteration times: 99
# [0.92156863 0.90196078 0.56862745 0.56862745]
# Repeating times: 60, Iteration times: 99
# [0.7254902  0.62745098 0.52941176 0.98039216]
# Repeating times: 61, Iteration times: 99
# [0.49019608 0.58823529 0.76470588 0.62745098]
# Repeating times: 62, Iteration times: 99
# [0.56862745 0.68627451 0.56862745 0.98039216]
# Repeating times: 63, Iteration times: 99
# [0.56862745 0.8627451  0.56862745 1.        ]
# Repeating times: 64, Iteration times: 99
# [0.88235294 0.64705882 0.64705882 0.74509804]
# Repeating times: 65, Iteration times: 99
# [0.60784314 0.60784314 0.60784314 0.60784314]
# Repeating times: 66, Iteration times: 99
# [0.52941176 0.52941176 0.52941176 0.52941176]
# Repeating times: 67, Iteration times: 99
# [0.68627451 0.52941176 0.66666667 0.66666667]
# Repeating times: 68, Iteration times: 99
# [0.56862745 0.56862745 0.80392157 0.70588235]
# Repeating times: 69, Iteration times: 99
# [0.56862745 0.56862745 0.56862745 1.        ]
# Repeating times: 70, Iteration times: 99
# [0.68627451 0.50980392 0.74509804 0.50980392]
# Repeating times: 71, Iteration times: 99
# [0.50980392 0.50980392 0.78431373 0.90196078]
# Repeating times: 72, Iteration times: 99
# [0.7254902  0.66666667 0.82352941 0.56862745]
# Repeating times: 73, Iteration times: 99
# [0.47058824 0.47058824 0.96078431 0.96078431]
# Repeating times: 74, Iteration times: 99
# [0.84313725 0.82352941 0.58823529 0.94117647]
# Repeating times: 75, Iteration times: 99
# [1.         0.66666667 0.8627451  0.80392157]
# Repeating times: 76, Iteration times: 99
# [0.58823529 1.         0.58823529 0.96078431]
# Repeating times: 77, Iteration times: 99
# [0.76470588 0.78431373 0.50980392 0.60784314]
# Repeating times: 78, Iteration times: 99
# [0.76470588 0.60784314 0.82352941 0.82352941]
# Repeating times: 79, Iteration times: 99
# [0.90196078 0.94117647 0.68627451 0.78431373]
# Repeating times: 80, Iteration times: 99
# [0.96078431 0.74509804 0.76470588 0.82352941]
# Repeating times: 81, Iteration times: 99
# [0.56862745 0.80392157 0.56862745 1.        ]
# Repeating times: 82, Iteration times: 99
# [0.49019608 0.62745098 0.62745098 0.90196078]
# Repeating times: 83, Iteration times: 99
# [0.50980392 0.50980392 0.50980392 0.66666667]
# Repeating times: 84, Iteration times: 99
# [0.54901961 0.70588235 0.54901961 0.90196078]
# Repeating times: 85, Iteration times: 99
# [0.62745098 0.56862745 0.56862745 0.62745098]
# Repeating times: 86, Iteration times: 99
# [0.98039216 0.98039216 0.52941176 1.        ]
# Repeating times: 87, Iteration times: 99
# [0.60784314 0.62745098 1.         0.80392157]
# Repeating times: 88, Iteration times: 99
# [0.70588235 0.62745098 0.54901961 0.54901961]
# Repeating times: 89, Iteration times: 99
# [0.58823529 0.58823529 0.98039216 0.58823529]
# Repeating times: 90, Iteration times: 99
# [0.58823529 0.76470588 0.58823529 0.68627451]
# Repeating times: 91, Iteration times: 99
# [0.62745098 0.94117647 0.62745098 0.62745098]
# Repeating times: 92, Iteration times: 99
# [0.58823529 0.58823529 0.84313725 0.58823529]
# Repeating times: 93, Iteration times: 99
# [0.66666667 0.52941176 0.82352941 0.52941176]
# Repeating times: 94, Iteration times: 99
# [1.         0.68627451 0.74509804 0.8627451 ]
# Repeating times: 95, Iteration times: 99
# [0.80392157 0.50980392 0.84313725 0.80392157]
# Repeating times: 96, Iteration times: 99
# [0.84313725 0.60784314 0.60784314 0.60784314]
# Repeating times: 97, Iteration times: 99
# [0.47058824 0.62745098 0.60784314 0.60784314]
# Repeating times: 98, Iteration times: 99
# [0.7254902  0.68627451 1.         0.60784314]
# Repeating times: 99, Iteration times: 99
# [0.49019608 0.58823529 0.49019608 0.90196078]

# %% [markdown]
# ## BoxPlot

# %%
## Generate labels for each pair of test data points
pair_labels = [f'{i+1}-{j+1}' for i in range(n_test) for j in range(i + 1, n_test)]

# Plot a boxplot of the correlations
plt.boxplot(all_correlations.T, vert=True, patch_artist=True)
plt.title('Boxplot of Correlations between Test Data Pairs')
plt.xlabel('Pair Index within Test Data')
plt.xticks(ticks=range(1, len(pair_labels) + 1), labels=pair_labels)
plt.ylabel('Correlation')

# Add mean values as points or text
for i, pair_corr in enumerate(all_correlations):
    mean_value = np.mean(pair_corr)
    plt.text(i + 1, mean_value, f'{mean_value:.5f}', ha='center', va='bottom', color='black', fontsize=10)   
    
plt.show()
